# %%
import pandas as pd
from sqlalchemy import create_engine

db_engine = create_engine("postgresql+psycopg2://postgres:admin1234@localhost:5432/bootcamp_final_project")
stock_ohlcv_url = "https://query1.finance.yahoo.com/v8/finance/chart/{symbol}?period1=1697904000&period2={timestamp}&interval=1d&events=history"

df_symbols = pd.read_sql("select * from symbols", con=db_engine)
symbol_to_id = dict(zip(df_symbols['symbol'], df_symbols['id']))
symbols = list(df_symbols["symbol"])

# %%
from sqlalchemy import text
import datetime
import time
import pytz
import requests


headers = {
  "User-Agent" : "Mozilla/5.0"
}

with db_engine.connect() as conn:
    try:
        conn.execute(text("DELETE FROM stock_ohlcv;"))
        conn.commit()  # Explicit commit for safety
        print("Deleted all existing data from 'stock_ohlcv' table.")
    except Exception as e:
        print(f"Error deleting data: {e}")
        # Optionally, raise or exit if critical

idx = 0
hktz = pytz.timezone('Asia/Hong_Kong')
now_hk = datetime.datetime.now(hktz)
ytd = now_hk.date() - datetime.timedelta(days=1)
ytd_6am_hk = hktz.localize(datetime.datetime.combine(ytd, datetime.time(6, 0)))
timestamp = int(ytd_6am_hk.astimezone(pytz.utc).timestamp())

for symbol in symbols:
  stock_id = symbol_to_id.get(symbol)
  if stock_id is None:
    print(f"No stock_id found for symbol: {symbol}")
    idx += 1
    print(f"Processed {idx}/{len(symbols)}: {symbol}")
    continue
  
  yahoo_symbol = symbol
  if symbol == "BRK.B":
    yahoo_symbol = "BRK-B"
  elif symbol == "BF.B":
    yahoo_symbol = "BF-B"

  url = stock_ohlcv_url.format(symbol=yahoo_symbol, timestamp = timestamp)
  response = requests.get(url, headers=headers)
  data = response.json()

  # Check if 'chart' and 'result' exist and are not empty
  if 'chart' not in data or not data['chart'] or 'result' not in data['chart'] or not data['chart']['result']:
    error_msg = data.get('chart', {}).get('error', 'No error message provided')
    print(f"No valid data for {symbol}: {error_msg}")
    idx += 1
    print(f"Processed {idx}/{len(symbols)}: {symbol}")
    continue
        
  result = data['chart']['result'][0]
        
  # Check if required keys exist in result
  required_keys = ['timestamp', 'indicators']
  if not all(key in result for key in required_keys):
    missing_keys = [key for key in required_keys if key not in result]
    print(f"Missing keys {missing_keys} in response for {symbol}: {result}")
    idx += 1
    print(f"Processed {idx}/{len(symbols)}: {symbol}")
    continue
        
  # Check if indicators contain quote
  if 'quote' not in result['indicators']:
    print(f"Missing 'quote' in indicators for {symbol}: {result['indicators']}")
    idx += 1
    print(f"Processed {idx}/{len(symbols)}: {symbol}")
    continue
        
  timestamps = result['timestamp']
  quote = result['indicators']['quote'][0]
  # Ensure lists are the same length
  if not (len(timestamps) == len(quote.get('close', []))):
    print(f"Data length mismatch for {symbol}")
    idx += 1
    print(f"Processed {idx}/{len(symbols)}: {symbol}")
    continue

  dates = pd.to_datetime(timestamps, unit='s').date

  ohlcv = {
    "stock_id" : [stock_id] * len(timestamps),
    "date" : dates,
    "open" : quote["open"],
    "high" : quote["high"],
    "low" : quote["low"],
    "close" : quote["close"],
    "volume" : quote["volume"]
    }

  df_ohlcv = pd.DataFrame(ohlcv)
  df_ohlcv.to_sql('stock_ohlcv', db_engine, if_exists='append', index=False)

  idx += 1
  print(f"Processed {idx}/{len(symbols)}: {symbol}")
  time.sleep(1)
# Out:
# Deleted all existing data from 'stock_ohlcv' table.
# Processed 1/503: MMM
# Processed 2/503: AOS
# Processed 3/503: ABT
# Processed 4/503: ABBV
# Processed 5/503: ACN
# Processed 6/503: ADBE
# Processed 7/503: AMD
# Processed 8/503: AES
# Processed 9/503: AFL
# Processed 10/503: A
# Processed 11/503: APD
# Processed 12/503: ABNB
# Processed 13/503: AKAM
# Processed 14/503: ALB
# Processed 15/503: ARE
# Processed 16/503: ALGN
# Processed 17/503: ALLE
# Processed 18/503: LNT
# Processed 19/503: ALL
# Processed 20/503: GOOGL
# Processed 21/503: GOOG
# Processed 22/503: MO
# Processed 23/503: AMZN
# Processed 24/503: AMCR
# Processed 25/503: AEE
# Processed 26/503: AEP
# Processed 27/503: AXP
# Processed 28/503: AIG
# Processed 29/503: AMT
# Processed 30/503: AWK
# Processed 31/503: AMP
# Processed 32/503: AME
# Processed 33/503: AMGN
# Processed 34/503: APH
# Processed 35/503: ADI
# Processed 36/503: AON
# Processed 37/503: APA
# Processed 38/503: APO
# Processed 39/503: AAPL
# Processed 40/503: AMAT
# Processed 41/503: APTV
# Processed 42/503: ACGL
# Processed 43/503: ADM
# Processed 44/503: ANET
# Processed 45/503: AJG
# Processed 46/503: AIZ
# Processed 47/503: T
# Processed 48/503: ATO
# Processed 49/503: ADSK
# Processed 50/503: ADP
# Processed 51/503: AZO
# Processed 52/503: AVB
# Processed 53/503: AVY
# Processed 54/503: AXON
# Processed 55/503: BKR
# Processed 56/503: BALL
# Processed 57/503: BAC
# Processed 58/503: BAX
# Processed 59/503: BDX
# Processed 60/503: BRK.B
# Processed 61/503: BBY
# Processed 62/503: TECH
# Processed 63/503: BIIB
# Processed 64/503: BLK
# Processed 65/503: BX
# Processed 66/503: XYZ
# Processed 67/503: BK
# Processed 68/503: BA
# Processed 69/503: BKNG
# Processed 70/503: BSX
# Processed 71/503: BMY
# Processed 72/503: AVGO
# Processed 73/503: BR
# Processed 74/503: BRO
# Processed 75/503: BF.B
# Processed 76/503: BLDR
# Processed 77/503: BG
# Processed 78/503: BXP
# Processed 79/503: CHRW
# Processed 80/503: CDNS
# Processed 81/503: CZR
# Processed 82/503: CPT
# Processed 83/503: CPB
# Processed 84/503: COF
# Processed 85/503: CAH
# Processed 86/503: KMX
# Processed 87/503: CCL
# Processed 88/503: CARR
# Processed 89/503: CAT
# Processed 90/503: CBOE
# Processed 91/503: CBRE
# Processed 92/503: CDW
# Processed 93/503: COR
# Processed 94/503: CNC
# Processed 95/503: CNP
# Processed 96/503: CF
# Processed 97/503: CRL
# Processed 98/503: SCHW
# Processed 99/503: CHTR
# Processed 100/503: CVX
# Processed 101/503: CMG
# Processed 102/503: CB
# Processed 103/503: CHD
# Processed 104/503: CI
# Processed 105/503: CINF
# Processed 106/503: CTAS
# Processed 107/503: CSCO
# Processed 108/503: C
# Processed 109/503: CFG
# Processed 110/503: CLX
# Processed 111/503: CME
# Processed 112/503: CMS
# Processed 113/503: KO
# Processed 114/503: CTSH
# Processed 115/503: COIN
# Processed 116/503: CL
# Processed 117/503: CMCSA
# Processed 118/503: CAG
# Processed 119/503: COP
# Processed 120/503: ED
# Processed 121/503: STZ
# Processed 122/503: CEG
# Processed 123/503: COO
# Processed 124/503: CPRT
# Processed 125/503: GLW
# Processed 126/503: CPAY
# Processed 127/503: CTVA
# Processed 128/503: CSGP
# Processed 129/503: COST
# Processed 130/503: CTRA
# Processed 131/503: CRWD
# Processed 132/503: CCI
# Processed 133/503: CSX
# Processed 134/503: CMI
# Processed 135/503: CVS
# Processed 136/503: DHR
# Processed 137/503: DRI
# Processed 138/503: DDOG
# Processed 139/503: DVA
# Processed 140/503: DAY
# Processed 141/503: DECK
# Processed 142/503: DE
# Processed 143/503: DELL
# Processed 144/503: DAL
# Processed 145/503: DVN
# Processed 146/503: DXCM
# Processed 147/503: FANG
# Processed 148/503: DLR
# Processed 149/503: DG
# Processed 150/503: DLTR
# Processed 151/503: D
# Processed 152/503: DPZ
# Processed 153/503: DASH
# Processed 154/503: DOV
# Processed 155/503: DOW
# Processed 156/503: DHI
# Processed 157/503: DTE
# Processed 158/503: DUK
# Processed 159/503: DD
# Processed 160/503: EMN
# Processed 161/503: ETN
# Processed 162/503: EBAY
# Processed 163/503: ECL
# Processed 164/503: EIX
# Processed 165/503: EW
# Processed 166/503: EA
# Processed 167/503: ELV
# Processed 168/503: EMR
# Processed 169/503: ENPH
# Processed 170/503: ETR
# Processed 171/503: EOG
# Processed 172/503: EPAM
# Processed 173/503: EQT
# Processed 174/503: EFX
# Processed 175/503: EQIX
# Processed 176/503: EQR
# Processed 177/503: ERIE
# Processed 178/503: ESS
# Processed 179/503: EL
# Processed 180/503: EG
# Processed 181/503: EVRG
# Processed 182/503: ES
# Processed 183/503: EXC
# Processed 184/503: EXE
# Processed 185/503: EXPE
# Processed 186/503: EXPD
# Processed 187/503: EXR
# Processed 188/503: XOM
# Processed 189/503: FFIV
# Processed 190/503: FDS
# Processed 191/503: FICO
# Processed 192/503: FAST
# Processed 193/503: FRT
# Processed 194/503: FDX
# Processed 195/503: FIS
# Processed 196/503: FITB
# Processed 197/503: FSLR
# Processed 198/503: FE
# Processed 199/503: FI
# Processed 200/503: F
# Processed 201/503: FTNT
# Processed 202/503: FTV
# Processed 203/503: FOXA
# Processed 204/503: FOX
# Processed 205/503: BEN
# Processed 206/503: FCX
# Processed 207/503: GRMN
# Processed 208/503: IT
# Processed 209/503: GE
# Processed 210/503: GEHC
# Processed 211/503: GEV
# Processed 212/503: GEN
# Processed 213/503: GNRC
# Processed 214/503: GD
# Processed 215/503: GIS
# Processed 216/503: GM
# Processed 217/503: GPC
# Processed 218/503: GILD
# Processed 219/503: GPN
# Processed 220/503: GL
# Processed 221/503: GDDY
# Processed 222/503: GS
# Processed 223/503: HAL
# Processed 224/503: HIG
# Processed 225/503: HAS
# Processed 226/503: HCA
# Processed 227/503: DOC
# Processed 228/503: HSIC
# Processed 229/503: HSY
# Processed 230/503: HPE
# Processed 231/503: HLT
# Processed 232/503: HOLX
# Processed 233/503: HD
# Processed 234/503: HON
# Processed 235/503: HRL
# Processed 236/503: HST
# Processed 237/503: HWM
# Processed 238/503: HPQ
# Processed 239/503: HUBB
# Processed 240/503: HUM
# Processed 241/503: HBAN
# Processed 242/503: HII
# Processed 243/503: IBM
# Processed 244/503: IEX
# Processed 245/503: IDXX
# Processed 246/503: ITW
# Processed 247/503: INCY
# Processed 248/503: IR
# Processed 249/503: PODD
# Processed 250/503: INTC
# Processed 251/503: ICE
# Processed 252/503: IFF
# Processed 253/503: IP
# Processed 254/503: IPG
# Processed 255/503: INTU
# Processed 256/503: ISRG
# Processed 257/503: IVZ
# Processed 258/503: INVH
# Processed 259/503: IQV
# Processed 260/503: IRM
# Processed 261/503: JBHT
# Processed 262/503: JBL
# Processed 263/503: JKHY
# Processed 264/503: J
# Processed 265/503: JNJ
# Processed 266/503: JCI
# Processed 267/503: JPM
# Processed 268/503: K
# Processed 269/503: KVUE
# Processed 270/503: KDP
# Processed 271/503: KEY
# Processed 272/503: KEYS
# Processed 273/503: KMB
# Processed 274/503: KIM
# Processed 275/503: KMI
# Processed 276/503: KKR
# Processed 277/503: KLAC
# Processed 278/503: KHC
# Processed 279/503: KR
# Processed 280/503: LHX
# Processed 281/503: LH
# Processed 282/503: LRCX
# Processed 283/503: LW
# Processed 284/503: LVS
# Processed 285/503: LDOS
# Processed 286/503: LEN
# Processed 287/503: LII
# Processed 288/503: LLY
# Processed 289/503: LIN
# Processed 290/503: LYV
# Processed 291/503: LKQ
# Processed 292/503: LMT
# Processed 293/503: L
# Processed 294/503: LOW
# Processed 295/503: LULU
# Processed 296/503: LYB
# Processed 297/503: MTB
# Processed 298/503: MPC
# Processed 299/503: MKTX
# Processed 300/503: MAR
# Processed 301/503: MMC
# Processed 302/503: MLM
# Processed 303/503: MAS
# Processed 304/503: MA
# Processed 305/503: MTCH
# Processed 306/503: MKC
# Processed 307/503: MCD
# Processed 308/503: MCK
# Processed 309/503: MDT
# Processed 310/503: MRK
# Processed 311/503: META
# Processed 312/503: MET
# Processed 313/503: MTD
# Processed 314/503: MGM
# Processed 315/503: MCHP
# Processed 316/503: MU
# Processed 317/503: MSFT
# Processed 318/503: MAA
# Processed 319/503: MRNA
# Processed 320/503: MHK
# Processed 321/503: MOH
# Processed 322/503: TAP
# Processed 323/503: MDLZ
# Processed 324/503: MPWR
# Processed 325/503: MNST
# Processed 326/503: MCO
# Processed 327/503: MS
# Processed 328/503: MOS
# Processed 329/503: MSI
# Processed 330/503: MSCI
# Processed 331/503: NDAQ
# Processed 332/503: NTAP
# Processed 333/503: NFLX
# Processed 334/503: NEM
# Processed 335/503: NWSA
# Processed 336/503: NWS
# Processed 337/503: NEE
# Processed 338/503: NKE
# Processed 339/503: NI
# Processed 340/503: NDSN
# Processed 341/503: NSC
# Processed 342/503: NTRS
# Processed 343/503: NOC
# Processed 344/503: NCLH
# Processed 345/503: NRG
# Processed 346/503: NUE
# Processed 347/503: NVDA
# Processed 348/503: NVR
# Processed 349/503: NXPI
# Processed 350/503: ORLY
# Processed 351/503: OXY
# Processed 352/503: ODFL
# Processed 353/503: OMC
# Processed 354/503: ON
# Processed 355/503: OKE
# Processed 356/503: ORCL
# Processed 357/503: OTIS
# Processed 358/503: PCAR
# Processed 359/503: PKG
# Processed 360/503: PLTR
# Processed 361/503: PANW
# Processed 362/503: PSKY
# Processed 363/503: PH
# Processed 364/503: PAYX
# Processed 365/503: PAYC
# Processed 366/503: PYPL
# Processed 367/503: PNR
# Processed 368/503: PEP
# Processed 369/503: PFE
# Processed 370/503: PCG
# Processed 371/503: PM
# Processed 372/503: PSX
# Processed 373/503: PNW
# Processed 374/503: PNC
# Processed 375/503: POOL
# Processed 376/503: PPG
# Processed 377/503: PPL
# Processed 378/503: PFG
# Processed 379/503: PG
# Processed 380/503: PGR
# Processed 381/503: PLD
# Processed 382/503: PRU
# Processed 383/503: PEG
# Processed 384/503: PTC
# Processed 385/503: PSA
# Processed 386/503: PHM
# Processed 387/503: PWR
# Processed 388/503: QCOM
# Processed 389/503: DGX
# Processed 390/503: RL
# Processed 391/503: RJF
# Processed 392/503: RTX
# Processed 393/503: O
# Processed 394/503: REG
# Processed 395/503: REGN
# Processed 396/503: RF
# Processed 397/503: RSG
# Processed 398/503: RMD
# Processed 399/503: RVTY
# Processed 400/503: ROK
# Processed 401/503: ROL
# Processed 402/503: ROP
# Processed 403/503: ROST
# Processed 404/503: RCL
# Processed 405/503: SPGI
# Processed 406/503: CRM
# Processed 407/503: SBAC
# Processed 408/503: SLB
# Processed 409/503: STX
# Processed 410/503: SRE
# Processed 411/503: NOW
# Processed 412/503: SHW
# Processed 413/503: SPG
# Processed 414/503: SWKS
# Processed 415/503: SJM
# Processed 416/503: SW
# Processed 417/503: SNA
# Processed 418/503: SOLV
# Processed 419/503: SO
# Processed 420/503: LUV
# Processed 421/503: SWK
# Processed 422/503: SBUX
# Processed 423/503: STT
# Processed 424/503: STLD
# Processed 425/503: STE
# Processed 426/503: SYK
# Processed 427/503: SMCI
# Processed 428/503: SYF
# Processed 429/503: SNPS
# Processed 430/503: SYY
# Processed 431/503: TMUS
# Processed 432/503: TROW
# Processed 433/503: TTWO
# Processed 434/503: TPR
# Processed 435/503: TRGP
# Processed 436/503: TGT
# Processed 437/503: TEL
# Processed 438/503: TDY
# Processed 439/503: TER
# Processed 440/503: TSLA
# Processed 441/503: TXN
# Processed 442/503: TPL
# Processed 443/503: TXT
# Processed 444/503: TMO
# Processed 445/503: TJX
# Processed 446/503: TKO
# Processed 447/503: TTD
# Processed 448/503: TSCO
# Processed 449/503: TT
# Processed 450/503: TDG
# Processed 451/503: TRV
# Processed 452/503: TRMB
# Processed 453/503: TFC
# Processed 454/503: TYL
# Processed 455/503: TSN
# Processed 456/503: USB
# Processed 457/503: UBER
# Processed 458/503: UDR
# Processed 459/503: ULTA
# Processed 460/503: UNP
# Processed 461/503: UAL
# Processed 462/503: UPS
# Processed 463/503: URI
# Processed 464/503: UNH
# Processed 465/503: UHS
# Processed 466/503: VLO
# Processed 467/503: VTR
# Processed 468/503: VLTO
# Processed 469/503: VRSN
# Processed 470/503: VRSK
# Processed 471/503: VZ
# Processed 472/503: VRTX
# Processed 473/503: VTRS
# Processed 474/503: VICI
# Processed 475/503: V
# Processed 476/503: VST
# Processed 477/503: VMC
# Processed 478/503: WRB
# Processed 479/503: GWW
# Processed 480/503: WAB
# No valid data for WBA: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# Processed 481/503: WBA
# Processed 482/503: WMT
# Processed 483/503: DIS
# Processed 484/503: WBD
# Processed 485/503: WM
# Processed 486/503: WAT
# Processed 487/503: WEC
# Processed 488/503: WFC
# Processed 489/503: WELL
# Processed 490/503: WST
# Processed 491/503: WDC
# Processed 492/503: WY
# Processed 493/503: WSM
# Processed 494/503: WMB
# Processed 495/503: WTW
# Processed 496/503: WDAY
# Processed 497/503: WYNN
# Processed 498/503: XEL
# Processed 499/503: XYL
# Processed 500/503: YUM
# Processed 501/503: ZBRA
# Processed 502/503: ZBH
# Processed 503/503: ZTS
